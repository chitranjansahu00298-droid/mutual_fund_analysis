# %%
from sqlalchemy import create_engine

engine = create_engine(
    "sqlite:////Users/chitranjansahu/Desktop/mutual_fund_analysis/data/db/bluestock_mf.db"
)

# %%
import pandas as pd

# Load datasets

fund_master = pd.read_csv(
    "/Users/chitranjansahu/Desktop/mutual_fund_analysis/data/raw/01_fund_master.csv"
)

nav_history = pd.read_csv(
    "/Users/chitranjansahu/Desktop/mutual_fund_analysis/data/raw/02_nav_history.csv"
)

aum_by_fund_house = pd.read_csv(
    "/Users/chitranjansahu/Desktop/mutual_fund_analysis/data/raw/03_aum_by_fund_house.csv"
)

monthly_sip_inflows = pd.read_csv(
    "/Users/chitranjansahu/Desktop/mutual_fund_analysis/data/raw/04_monthly_sip_inflows.csv"
)

category_inflows = pd.read_csv(
    "/Users/chitranjansahu/Desktop/mutual_fund_analysis/data/raw/05_category_inflows.csv"
)

industry_folio_count = pd.read_csv(
    "/Users/chitranjansahu/Desktop/mutual_fund_analysis/data/raw/06_industry_folio_count.csv"
)

scheme_performance = pd.read_csv(
    "/Users/chitranjansahu/Desktop/mutual_fund_analysis/data/raw/07_scheme_performance.csv"
)

investor_transactions = pd.read_csv(
    "/Users/chitranjansahu/Desktop/mutual_fund_analysis/data/raw/08_investor_transactions.csv"
)

portfolio_holdings = pd.read_csv(
    "/Users/chitranjansahu/Desktop/mutual_fund_analysis/data/raw/09_portfolio_holdings.csv"
)

benchmark_indices = pd.read_csv(
    "/Users/chitranjansahu/Desktop/mutual_fund_analysis/data/raw/10_benchmark_indices.csv"
)

print("All datasets loaded successfully!")
# Out:
# All datasets loaded successfully!

# %%
# 1. Fund Master
fund_master.to_sql(
    "dim_fund",
    engine,
    if_exists="replace",
    index=False
)

# 2. NAV History
nav_history.to_sql(
    "fact_nav",
    engine,
    if_exists="replace",
    index=False
)

# 3. AUM by Fund House
aum_by_fund_house.to_sql(
    "fact_aum",
    engine,
    if_exists="replace",
    index=False
)

# 4. Monthly SIP Inflows
monthly_sip_inflows.to_sql(
    "monthly_sip_inflows",
    engine,
    if_exists="replace",
    index=False
)

# 5. Category Inflows
category_inflows.to_sql(
    "category_inflows",
    engine,
    if_exists="replace",
    index=False
)

# 6. Industry Folio Count
industry_folio_count.to_sql(
    "industry_folio_count",
    engine,
    if_exists="replace",
    index=False
)

# 7. Scheme Performance
scheme_performance.to_sql(
    "fact_performance",
    engine,
    if_exists="replace",
    index=False
)

# 8. Investor Transactions
investor_transactions.to_sql(
    "fact_transactions",
    engine,
    if_exists="replace",
    index=False
)

# 9. Portfolio Holdings
portfolio_holdings.to_sql(
    "portfolio_holdings",
    engine,
    if_exists="replace",
    index=False
)

# 10. Benchmark Indices
benchmark_indices.to_sql(
    "benchmark_indices",
    engine,
    if_exists="replace",
    index=False
)

print("All tables loaded successfully into SQLite database!")
# Out:
# All tables loaded successfully into SQLite database!

# %%
import sqlite3

conn = sqlite3.connect(
    "/Users/chitranjansahu/Desktop/mutual_fund_analysis/data/db/bluestock_mf.db"
)

print("Database Created Successfully")
# Out:
# Database Created Successfully
